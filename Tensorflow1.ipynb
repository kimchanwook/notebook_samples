# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Basic-Classification-(keras)" data-toc-modified-id="Basic-Classification-(keras)-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Basic Classification (keras)</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Import-the-Fashion-MNIST-dataset" data-toc-modified-id="Import-the-Fashion-MNIST-dataset-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>Import the Fashion MNIST dataset</a></span></li><li><span><a href="#Explore-the-data" data-toc-modified-id="Explore-the-data-1.0.2"><span class="toc-item-num">1.0.2&nbsp;&nbsp;</span>Explore the data</a></span></li><li><span><a href="#Preprocess-the-data" data-toc-modified-id="Preprocess-the-data-1.0.3"><span class="toc-item-num">1.0.3&nbsp;&nbsp;</span>Preprocess the data</a></span></li><li><span><a href="#Build-the-model--(notes)" data-toc-modified-id="Build-the-model--(notes)-1.0.4"><span class="toc-item-num">1.0.4&nbsp;&nbsp;</span>Build the model  (notes)</a></span></li><li><span><a href="#Train-the-model" data-toc-modified-id="Train-the-model-1.0.5"><span class="toc-item-num">1.0.5&nbsp;&nbsp;</span>Train the model</a></span></li><li><span><a href="#Evaluate-accuracy-on-test-data" data-toc-modified-id="Evaluate-accuracy-on-test-data-1.0.6"><span class="toc-item-num">1.0.6&nbsp;&nbsp;</span>Evaluate accuracy on test data</a></span></li><li><span><a href="#Make-predictions-about-any-images" data-toc-modified-id="Make-predictions-about-any-images-1.0.7"><span class="toc-item-num">1.0.7&nbsp;&nbsp;</span>Make predictions about any images</a></span></li><li><span><a href="#Plot-results-of-predictions" data-toc-modified-id="Plot-results-of-predictions-1.0.8"><span class="toc-item-num">1.0.8&nbsp;&nbsp;</span>Plot results of predictions</a></span></li><li><span><a href="#Use-model-to-make-prediction-on-a-single-image" data-toc-modified-id="Use-model-to-make-prediction-on-a-single-image-1.0.9"><span class="toc-item-num">1.0.9&nbsp;&nbsp;</span>Use model to make prediction on a single image</a></span></li></ul></li></ul></li><li><span><a href="#Text-Classification-(keras)" data-toc-modified-id="Text-Classification-(keras)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Text Classification (keras)</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Import-IMDB-dataset" data-toc-modified-id="Import-IMDB-dataset-2.0.1"><span class="toc-item-num">2.0.1&nbsp;&nbsp;</span>Import IMDB dataset</a></span></li><li><span><a href="#Explore-the-data" data-toc-modified-id="Explore-the-data-2.0.2"><span class="toc-item-num">2.0.2&nbsp;&nbsp;</span>Explore the data</a></span></li><li><span><a href="#Convert-the-integers-back-to-words" data-toc-modified-id="Convert-the-integers-back-to-words-2.0.3"><span class="toc-item-num">2.0.3&nbsp;&nbsp;</span>Convert the integers back to words</a></span></li><li><span><a href="#Prepare-the-data" data-toc-modified-id="Prepare-the-data-2.0.4"><span class="toc-item-num">2.0.4&nbsp;&nbsp;</span>Prepare the data</a></span></li><li><span><a href="#Build-the-model" data-toc-modified-id="Build-the-model-2.0.5"><span class="toc-item-num">2.0.5&nbsp;&nbsp;</span>Build the model</a></span></li><li><span><a href="#Compile-the-model:-Loss-function-and-Optimizer" data-toc-modified-id="Compile-the-model:-Loss-function-and-Optimizer-2.0.6"><span class="toc-item-num">2.0.6&nbsp;&nbsp;</span>Compile the model: Loss function and Optimizer</a></span></li><li><span><a href="#Create-Validation-set" data-toc-modified-id="Create-Validation-set-2.0.7"><span class="toc-item-num">2.0.7&nbsp;&nbsp;</span>Create Validation set</a></span></li><li><span><a href="#Train-the-model" data-toc-modified-id="Train-the-model-2.0.8"><span class="toc-item-num">2.0.8&nbsp;&nbsp;</span>Train the model</a></span></li><li><span><a href="#Evaluate-the-model" data-toc-modified-id="Evaluate-the-model-2.0.9"><span class="toc-item-num">2.0.9&nbsp;&nbsp;</span>Evaluate the model</a></span></li><li><span><a href="#Predictions" data-toc-modified-id="Predictions-2.0.10"><span class="toc-item-num">2.0.10&nbsp;&nbsp;</span>Predictions</a></span></li><li><span><a href="#Plot-results" data-toc-modified-id="Plot-results-2.0.11"><span class="toc-item-num">2.0.11&nbsp;&nbsp;</span>Plot results</a></span></li></ul></li></ul></li></ul></div>

# %%
import uproot
import sys
import struct
import math
import numpy                  as np
import pandas                 as pd
import seaborn                as sns
import matplotlib.pyplot      as plt
import tensorflow             as tf
from   tensorflow             import keras
from   mpl_toolkits           import mplot3d
from   mpl_toolkits.mplot3d   import Axes3D
# from   rbDST2dict             import rbDST2dict_chan as frz      #rbDST2dict=dir, rbDST2dict.py=module, rbDST2dict()=class

#To increase the cell width + load Images
from IPython.core.display import display, HTML, Image
# display(HTML("<style>.container { width:100% !important; }</style>"))
#Pandas options
pd.options.display.max_columns = None
# pd.options.display.max_rows    = None

# %% [markdown]
# #  Basic Classification (keras)

# %% [markdown]
# ### Import the Fashion MNIST dataset

# %%
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# ### Explore the data

# %%
train_images.__class__

# %%
train_labels.__class__

# %%
fashion_mnist.__package__

# %%
train_images.shape

# %%
train_labels.shape

# %%
len(train_labels)

# %%
train_labels[0:100]

# %%
test_images.shape

# %%
len(test_labels)

# %%
train_images[0].shape

# %%
test_labels[0:100]

# %% [markdown]
# ### Preprocess the data

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)

# %% [markdown]
# * Scale 0 - 255 to a range of 0 - 1.
# * Cast the datatype of the images from integers to floats

# %%
train_images = train_images / 255.0
test_images  = test_images  / 255.0

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.xticks([])      #erases coordinate labels on axis
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
#     plt.imshow(train_images[i])
    plt.xlabel(class_names[train_labels[i]])

# %% [markdown]
# ### Build the model  (notes)

# %% [markdown]
# #### Definitions (justnotes)

# %% [markdown]
# __`Definitions`__
# * __layer__
#   * core building block of neural networks
#   * data-processing module that filters the data
#   * extract _representations_ out of the data fed into them.
# * __Dense__ layers
#   * densely connected neural layers also known as _fully connected_
# * __loss function__
#   * measure of performance on the training data
# * __optimizer__
#   * mechanism through which the NN will update itself based on the data it sees and the loss function
# * __Metrics__ to monitor quality of training
#   * accuracies, efficiency, purities, ... etc

# %% [markdown]
# #### Set up the layers  (notes)

# %%
model = keras.Sequential([keras.layers.Flatten(input_shape=(28,28)), 
                          keras.layers.Dense(128, activation=tf.nn.relu),
                          keras.layers.Dense(10, activation=tf.nn.softmax)])

# %% [markdown]
# __`Code Explanation`__
# * __keras.Sequential__ model is a linear stack of layers
# * __tf.keras.layers.Flatten__ transforms the format of the images from a 2d-array (28x28 pixels) to a 1d-array
#   (28*28=784pixels)
# * __tf.keras.layers.Dense__
#   * the network will consist of two dense (fully-connected) neural layers.
#     * 1st dense neural layer has 128 nodes
#       * activation function describes what kind of output one wants from the layer
#       * tf.nn.relu = Re(ctified) L(inear) U(nit)
#         * As results from each layer needs to yield a specific representation of result (i.e. 0 or 1), there
#           for we need to
#           rectify the result using a function and in this case, a linear function.
#     * 2nd dense neural layer has 10-node softmax layer - `This is where __prediction__ happens`
#       * tf.nn.softmax = returns an array of 10 probability scores that sum to 1 - Normalisation of
#         sum(input)=1
#         * each node contains a score that indicates the probability that the current image belong to one of 10
#           classes

# %% [markdown]
# #### The engine of neural networks (justnotes)

# %% [markdown]
# __`Framework of NN`__
# * Each neural netwrork operates on input data as follow:
#   $$ output = relu(dot(W, input) + b) $$
#   * $b=trainable\ parameter$ are tensors that is attribute of the _bias_
#       * Bias is like the intercept added in a linear equation
#           * adjust the output along with the weighted sum of inputs
#           * adjusted to help the model to fit best for the given data
#   * $W=weights$ (_coefficients_) - tensor that is an attribute of the _kernel_
#     * Initially, these weights are filled with small randome values, _random initialization_
#     * gradual adjustment of these weights after each iteration in _training loop_ = training the model data
#       1. Draw training samples _x_ and corresponding targets _y_
#       2. Run the network on _x_ (step called _forward pass_) to obtain predictions _y_pred_
#       3. Compute the loss of the network on the batch: a measure of the mismatch between _y_pred_ and _y_.
#       4. __Optimizer__: Update all weights of the network in a way that slightly reduces the loss on this batch.
#         * How can you compute how the coefficient should be altered? improved?
#           1. Naive solution
#             * freeze all weights in the network except the one scalar coefficient being considered and try new values
#               untill it improves.
#           2. Better solution (_stochastic gradient descent_ SGD algorithm)
#             * Since all tensor operations are _differentiable_, compute _graduent_ of the loss function with regards
#               to the network's coefficients/parameters. Then, move the coefficients in the opposite direction from the
#               gradient, thus decreasing the loss:
#               $$ W := W - (step\ *\ gradient) $$
#             * Find the minimum and alter the coefficients toward minimum.
#             * _stochastic_ refers to the fact that each batch of data is drawn at random.
#           3. SGD with momentum
#             * use gradient of not only the current value (current velocity), but also the past value (past velocity). Thus,
#               it allows the see local minimum + global minimum.
#
# * __Optimizer__ and __loss function__ are what determines the NN algorithm - `where physics can be applied`.
#   * I assume most of the optimizers use statistical methods using traing data and computing relations between parameters of
#     training data to find a way to best update Weights.
#   * However, if you have external knowledge (physics in our case: __`relativistic kinematics`__) about the system that you
#     can put as constraints when optimizing, it will yield better results:
#     * Scattering angle limitation
#       * For example, at certain forbidden angles, angles weigh less than momentum, energy, ... $\rightarrow$ update weights
#         in such a way that the layers use parameters such as momentum, energy , etc more than scattering angles.

# %%
# Image(filename="loss_function_1d.png")

# %%
# Image(filename="loss_function_2d.png")

# %% [markdown]
# #### Compile the model: Optimizer + Loss function  (notes)

# %% [markdown]
# * Optimizer `AdamOptimizer()` - Adaptive moment estimation
#   * See paper by Kingma
# * Loss function `sparse_categorical_crossentropy`
#   * See Information Theory for definition of entropy

# %%
model.compile(optimizer = tf.train.AdamOptimizer(), 
              loss      = 'sparse_categorical_crossentropy',
              metrics   = ['accuracy'])

# %% [markdown]
# ###  Train the model

# %%
model.fit(train_images, train_labels, epochs=5)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 3s 51us/step - loss: 0.5015 - acc: 0.8237
# Epoch 2/5
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.3743 - acc: 0.8643
# Epoch 3/5
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.3390 - acc: 0.8761
# Epoch 4/5
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.3133 - acc: 0.8850
# Epoch 5/5
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.2966 - acc: 0.8906

# %% [markdown]
# * epoch=5 means to do 5 iterations of one whole traing data
# * model.fit method - the model is "fit" to the training data
# * Make predictions on trainig data: Accuracy 82% ~ 89%

# %% [markdown]
# ### Evaluate accuracy on test data

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print("Test accuracy:", test_acc)
# Out:
# 10000/10000 [==============================] - 0s 34us/step
# Test accuracy: 0.8724

# %% [markdown]
# * Accuracy of prediction on test data is 86%, which is a less than the accuracy of prediction on training data.
#   * Such gap is due to __`Overfitting`__: instances when the model performs worse in test data than training data.

# %% [markdown]
# ### Make predictions about any images

# %%
predictions = model.predict(test_images)

# %%
predictions[0]
# Out:
# array([1.61640074e-07, 1.61228385e-07, 4.73330743e-08, 1.15166728e-07,
#        8.61350998e-07, 4.82263102e-04, 7.02228817e-07, 5.66683970e-02,
#        1.48852605e-05, 9.42832530e-01], dtype=float32)

# %% [markdown]
# * prediction[0] is an array of 10 elements, each corresponding to its likelyhood to be each of 10 class items.
# * For prediction[0] (first item in the test_image) is most likely to be an Ankle boot

# %%
np.argmax(predictions[0])
# Out:
# 9

# %%
test_labels[0]
# Out:
# 9

# %% [markdown]
# ### Plot results of predictions

# %%
def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    #display image      
    plt.imshow(img, cmap=plt.cm.binary)
    #predicted label - blue:corred, red:wrong
    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'
    #x labels
    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label], 100*np.max(predictions_array),
                                          class_names[true_label]), color=color)   #color = xlabel's arugment
    
def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array[i], true_label[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0,1])
    predicted_label = np.argmax(predictions_array)
    #set color
    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %%
#0th image, prediction, and prediction array
i=0
image = plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions, test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions, test_labels)
# image.savefig("0th_image")

# %%
#0th image, prediction, and prediction array
i=12
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions, test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions, test_labels)

# %%
#Several images with predictions. Correct prediction - blue, incorred prediction - red
num_rows   = 6
num_cols   = 3
num_images = num_rows * num_cols
image_prediction = plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2*num_cols, 2*i+1)
    plot_image(i, predictions, test_labels, test_images)
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i, predictions, test_labels)
image_prediction.savefig("image_prediction")

# %% [markdown]
# ### Use model to make prediction on a single image

# %%
#grap an image from the test dataset
img = test_images[0]
print(img.shape)
# Out:
# (28, 28)

# %%
#need to make the image 3d tensor, b/c tf.keras models are optimized to make predictions on a batch of images
img = (np.expand_dims(img,0))
print(img.shape)
# Out:
# (1, 28, 28)

# %%
predictions_single = model.predict(img)
print(predictions_single)
# Out:
# [[1.6164006e-07 1.6122821e-07 4.7332978e-08 1.1516660e-07 8.6134924e-07
#   4.8226304e-04 7.0222876e-07 5.6668445e-02 1.4885230e-05 9.4283241e-01]]

# %%
np.argmax(predictions_single[0])
# Out:
# 9

# %%
image_prediction_single = plt.figure(figsize=(10, 4))
plot_value_array(0, predictions_single, test_labels)
plt.xticks(range(10), class_names, rotation=45)
plt.show()
image_prediction_single.savefig("image_prediction_single")

# %% [markdown]
# #  Text Classification (keras)

# %% [markdown]
# ### Import IMDB dataset

# %%
imdb = keras.datasets.imdb
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)

# %% [markdown]
# ### Explore the data

# %% [markdown]
# * Preprocessed data
#   * Array of integers representing the words of the movie review $\rightarrow$ train_data = 25000 lists of ints
#   * Each label is  an integer value of either 0 or 1: 0 = negative review and 1 = positive review

# %%
print(train_data.shape)
print(train_labels.shape)
print(test_data.shape)
print(test_labels.shape)
# Out:
# (25000,)
# (25000,)
# (25000,)
# (25000,)

# %%
print("Training entries: {}, labels: {}".format(len(train_data), len(train_labels)))
# Out:
# Training entries: 25000, labels: 25000

# %%
train_data[24999]
# Out:
# [1,
#  17,
#  6,
#  194,
#  337,
#  7,
#  4,
#  204,
#  22,
#  45,
#  254,
#  8,
#  106,
#  14,
#  123,
#  4,
#  2,
#  270,
#  2,
#  5,
#  2,
#  2,
#  732,
#  2098,
#  101,
#  405,
#  39,
#  14,
#  1034,
#  4,
#  1310,
#  9,
#  115,
#  50,
#  305,
#  12,
#  47,
#  4,
#  168,
#  5,
#  235,
#  7,
#  38,
#  111,
#  699,
#  102,
#  7,
#  4,
#  4039,
#  9245,
#  9,
#  24,
#  6,
#  78,
#  1099,
#  17,
#  2345,
#  2,
#  21,
#  27,
#  9685,
#  6139,
#  5,
#  2,
#  1603,
#  92,
#  1183,
#  4,
#  1310,
#  7,
#  4,
#  204,
#  42,
#  97,
#  90,
#  35,
#  221,
#  109,
#  29,
#  127,
#  27,
#  118,
#  8,
#  97,
#  12,
#  157,
#  21,
#  6789,
#  2,
#  9,
#  6,
#  66,
#  78,
#  1099,
#  4,
#  631,
#  1191,
#  5,
#  2642,
#  272,
#  191,
#  1070,
#  6,
#  7585,
#  8,
#  2197,
#  2,
#  2,
#  544,
#  5,
#  383,
#  1271,
#  848,
#  1468,
#  2,
#  497,
#  2,
#  8,
#  1597,
#  8778,
#  2,
#  21,
#  60,
#  27,
#  239,
#  9,
#  43,
#  8368,
#  209,
#  405,
#  10,
#  10,
#  12,
#  764,
#  40,
#  4,
#  248,
# ...

# %%
print(len(train_data))
print(len(train_data[0]))
# Out:
# 25000
# 218

# %% [markdown]
# ### Convert the integers back to words

# %%
#Dictionary mapping words to an integer index
word_index = imdb.get_word_index()
word_index

#First indices are reserved
word_index = {k: (v+3) for k,v in word_index.items()}
word_index["<PAD>"]    = 0
word_index["<START>"]  = 1
word_index["<UNK>"]    = 2
word_index["<UNUSED>"] = 3

#Reverse the order of key and value of the word_index dictionary
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

# %%
#Put a space inbetween every word in the word
def decode_review(text):
    return ' '.join([ reverse_word_index.get(i, '?') for i in text ])

# %%
reverse_word_index
# Out:
# {0: '<PAD>',
#  1: '<START>',
#  2: '<UNK>',
#  3: '<UNUSED>',
#  4: 'the',
#  5: 'and',
#  6: 'a',
#  7: 'of',
#  8: 'to',
#  9: 'is',
#  10: 'br',
#  11: 'in',
#  12: 'it',
#  13: 'i',
#  14: 'this',
#  15: 'that',
#  16: 'was',
#  17: 'as',
#  18: 'for',
#  19: 'with',
#  20: 'movie',
#  21: 'but',
#  22: 'film',
#  23: 'on',
#  24: 'not',
#  25: 'you',
#  26: 'are',
#  27: 'his',
#  28: 'have',
#  29: 'he',
#  30: 'be',
#  31: 'one',
#  32: 'all',
#  33: 'at',
#  34: 'by',
#  35: 'an',
#  36: 'they',
#  37: 'who',
#  38: 'so',
#  39: 'from',
#  40: 'like',
#  41: 'her',
#  42: 'or',
#  43: 'just',
#  44: 'about',
#  45: "it's",
#  46: 'out',
#  47: 'has',
#  48: 'if',
#  49: 'some',
#  50: 'there',
#  51: 'what',
#  52: 'good',
#  53: 'more',
#  54: 'when',
#  55: 'very',
#  56: 'up',
#  57: 'no',
#  58: 'time',
#  59: 'she',
#  60: 'even',
#  61: 'my',
#  62: 'would',
#  63: 'which',
#  64: 'only',
#  65: 'story',
#  66: 'really',
#  67: 'see',
#  68: 'their',
#  69: 'had',
# ...

# %%
train_data
# Out:
# array([list([1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]),
# ...

# %%
print(train_data[0])
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]

# %%
for i in train_data:
    print(len(train_data[i]))
# Out:
# 218
# 189
# 141
# 550
# 147
# 43
# 123
# 562
# 233
# 130
# 450
# 99
# 117
# 238
# 109
# 129
# 163
# 752
# 212
# 177
# 129
# 140
# 256
# 888
# 93
# 142
# 220
# 193
# 171
# 221
# 174
# 647
# 233
# 162
# 597
# 234
# 51
# 336
# 139
# 231
# 704
# 142
# 861
# 132
# 122
# 570
# 55
# 214
# 103
# 186
# 113
# 169
# 469
# 138
# 302
# 766
# 351
# 146
# 59
# 206
# 107
# 152
# 186
# 431
# 147
# 684
# 383
# 324
# 252
# 263
# 787
# 211
# 314
# 118
# 390
# 132
# 710
# 306
# 167
# 115
# 95
# 158
# 156
# 82
# 502
# 314
# 190
# 174
# 60
# 145
# 214
# 659
# 408
# 515
# 461
# 202
# 238
# 170
# 107
# 171
# 158
# 145
# 790
# 258
# 287
# 67
# 123
# 975
# 775
# 236
# 195
# 274
# 214
# 91
# 1038
# 815
# 183
# 206
# 50
# 118
# 147
# 141
# 60
# 56
# 439
# 439
# 213
# 144
# 533
# 303
# 203
# 563
# 129
# 153
# 55
# 92
# 174
# 187
# 183
# 165
# 78
# 198
# 156
# 223
# 127
# 61
# 362
# 84
# 57
# 176
# 159
# 57
# 159
# 165
# 213
# 194
# 149
# 130
# 203
# 19
# 98
# 466
# 525
# 130
# 322
# 153
# 408
# 215
# 472
# 143
# ...

# %%
decode_review(train_data[0])
# Out:
# "<START> this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert <UNK> is an amazing actor and now the same being director <UNK> father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for <UNK> and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also <UNK> to the two little boy's that played the <UNK> of norman and paul they were just brilliant children are often left out of the <UNK> list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for 
# ...

# %% [markdown]
# ### Prepare the data

# %% [markdown]
# * The input (reviews; currently array of _"list"_ of ints) must be converted to tensors (3d arrays) before put to NN models. 2 way:
#   1. Convert arrays into vectors of 0s and 1s. For ex, [3,5] $\rightarrow$ 10,000-dim vector that is all zeroes except for
#      indices 3 and 5, which are 1s. Use this as the first layer in the NN model.
#   2. Pad the arrays so they all have the same length, then create a tensor of shape (max\_length * num\_review). We will use
#      this method (w/ pad_sequences function).

# %%
train_data = keras.preprocessing.sequence.pad_sequences(train_data, value=word_index['<PAD>'], padding='post', 
                                                        maxlen=256)
test_data  = keras.preprocessing.sequence.pad_sequences(test_data, value=word_index['<PAD>'], padding='post', 
                                                        maxlen=256)

# %%
for i in train_data:
    print(len(train_data[i]))
# Out:
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# 256
# ...

# %%
print(train_data[0])
# Out:
# [   1   14   22   16   43  530  973 1622 1385   65  458 4468   66 3941
#     4  173   36  256    5   25  100   43  838  112   50  670    2    9
#    35  480  284    5  150    4  172  112  167    2  336  385   39    4
#   172 4536 1111   17  546   38   13  447    4  192   50   16    6  147
#  2025   19   14   22    4 1920 4613  469    4   22   71   87   12   16
#    43  530   38   76   15   13 1247    4   22   17  515   17   12   16
#   626   18    2    5   62  386   12    8  316    8  106    5    4 2223
#  5244   16  480   66 3785   33    4  130   12   16   38  619    5   25
#   124   51   36  135   48   25 1415   33    6   22   12  215   28   77
#    52    5   14  407   16   82    2    8    4  107  117 5952   15  256
#     4    2    7 3766    5  723   36   71   43  530  476   26  400  317
#    46    7    4    2 1029   13  104   88    4  381   15  297   98   32
#  2071   56   26  141    6  194 7486   18    4  226   22   21  134  476
# ...

# %%
decode_review(train_data[0])
# Out:
# "<START> this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert <UNK> is an amazing actor and now the same being director <UNK> father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for <UNK> and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also <UNK> to the two little boy's that played the <UNK> of norman and paul they were just brilliant children are often left out of the <UNK> list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for 
# ...

# %%
decode_review(train_data[3])
# Out:
# "twenty first century to hang out in <UNK> but he is raised on the western <UNK> among a <UNK> speaking community br br yet there is a deeper conflict within him he <UNK> to know the truth the truth behind his <UNK> ancient stories where does fiction end and he wants to know the truth behind the death of his parents br br he is pulled to make a last <UNK> journey to the <UNK> of one of <UNK> most <UNK> mountains can the truth be told or is it all in stories br br in this story about stories we <UNK> bloody battles <UNK> lovers the <UNK> of old and the sometimes more <UNK> <UNK> of accepted truth in doing so we each connect with <UNK> as he lives the story of his own life br br <UNK> the <UNK> <UNK> is probably the most honest <UNK> and genuinely beautiful film of scotland ever made like <UNK> i got slightly annoyed with the <UNK> of hanging stories on more stories but also like <UNK> i <UNK> this once i saw the <UNK> picture ' forget the box office <UNK> of braveheart and its like yo
# ...

# %% [markdown]
# ### Build the model

# %%
vocab_size = 10000

model = keras.Sequential()
model.add(keras.layers.Embedding(vocab_size, 16))
model.add(keras.layers.GlobalAveragePooling1D())
model.add(keras.layers.Dense(16, activation=tf.nn.relu))
model.add(keras.layers.Dense(1,  activation=tf.nn.sigmoid))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding (Embedding)        (None, None, 16)          160000
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 17
# ...
# Total params: 160,289
# Trainable params: 160,289
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# * __keras.layers.Embedding(vocal_size, 16)__ [Chollet pg185]
#   * way of associating a vector with a word with the use of _dense word vectors_ also called _word
#     embeddings_. Simply put, `Mapping human language into a geometric space`.
#     * Takes integer (an index) as input and looks up these integers in an internal dictionary and returns the
#       associated vector.
#     * Input = (batch_size(# of vacabs in word index) , embedding\_dim(dim of dense vector))
#     * Output = (batch_size, sequence_length (# words in each review), embedding\_dim(dim of vector))
#   * Problem is that resulting embedding space has no structure:
#     * words _accurate_ and _exact_ may end up with completely different embeddings, even though they are
#       interchangeable in most sentences.
# * __keras.layers.GlobalAveragePooling1D()__
#   * returns a fixed-length output vector for each example by averaging over sequence length.
#     * Isn't this losing information? Yes
#   * allows the model to handle input of variable length.
# * __keras.layers.Dense(16, activation=tf.nn.relu)__
#   * 1st dense neural layer has 16 nodes (hidden units)
#     * tf.nn.relu = Re(ctified) L(inear) U(nit)
#       * As results from each layer needs to yield a specific representation of result (i.e. 1 - 16), there
#         for we need to rectify the result using a function and in this case, a linear function.
#   * `If too many nodes $\rightarrow$ overfitting`
# * __keras.layers.Dense(1,  activation=tf.nn.sigmoid)__
#   * 2nd dense neural layer has 1 node
#     * from those results from 16 nodes from previous layer, it yields a final decision between 0 or 1, using
#       the sigmoid function.

# %% [markdown]
# ### Compile the model: Loss function and Optimizer

# %%
model.compile(optimizer=tf.train.AdamOptimizer(), loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# * Since this is a binary classification, the model outputs a probability of being 0 or 1. We will use
#   __binary crossentropy__ lossfuntion

# %% [markdown]
# ### Create Validation set

# %%
x_val = train_data[:10000]
partial_x_train = train_data[10000:]

y_val = train_labels[:10000]
partial_y_train = train_labels[10000:]

# %% [markdown]
# ### Train the model

# %%
history = model.fit(partial_x_train, partial_y_train, epochs=40, batch_size=512, 
                    validation_data=(x_val, y_val), verbose=1)
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/40
# 15000/15000 [==============================] - 1s 65us/step - loss: 0.6921 - acc: 0.5433 - val_loss: 0.6902 - val_acc: 0.6538
# Epoch 2/40
# 15000/15000 [==============================] - 1s 43us/step - loss: 0.6867 - acc: 0.7115 - val_loss: 0.6825 - val_acc: 0.7102
# Epoch 3/40
# 15000/15000 [==============================] - 1s 41us/step - loss: 0.6738 - acc: 0.7585 - val_loss: 0.6651 - val_acc: 0.7630
# Epoch 4/40
# 15000/15000 [==============================] - 1s 46us/step - loss: 0.6489 - acc: 0.7706 - val_loss: 0.6374 - val_acc: 0.7748
# Epoch 5/40
# 15000/15000 [==============================] - 1s 44us/step - loss: 0.6123 - acc: 0.8013 - val_loss: 0.5982 - val_acc: 0.7919
# Epoch 6/40
# 15000/15000 [==============================] - 1s 43us/step - loss: 0.5662 - acc: 0.8175 - val_loss: 0.5540 - val_acc: 0.8058
# Epoch 7/40
# ...

# %% [markdown]
# * 40 epochs = 40 iterations in mini-batches of 512 samples
#   * Accuracy increased as iterated

# %% [markdown]
# ### Evaluate the model

# %%
results = model.evaluate(test_data, test_labels)
print(results)      #loss and accuracy are returned
# Out:
# 25000/25000 [==============================] - 1s 23us/step
# [0.33381409286022184, 0.87256]

# %% [markdown]
# ### Predictions

# %%
predictions = model.predict(test_data)

# %%
for i in range(0, len(test_data)):    
    print("Prediction of review #",i,"=\t",predictions[i], "\t True values = ", test_labels[i])
# Out:
# Prediction of review # 0 =	 [0.07962989] 	 True values =  0
# Prediction of review # 1 =	 [0.99942917] 	 True values =  1
# Prediction of review # 2 =	 [0.7969091] 	 True values =  1
# Prediction of review # 3 =	 [0.75714105] 	 True values =  0
# Prediction of review # 4 =	 [0.9960615] 	 True values =  1
# Prediction of review # 5 =	 [0.94153714] 	 True values =  1
# Prediction of review # 6 =	 [0.9598277] 	 True values =  1
# Prediction of review # 7 =	 [0.01458292] 	 True values =  0
# Prediction of review # 8 =	 [0.97375906] 	 True values =  0
# Prediction of review # 9 =	 [0.99958986] 	 True values =  1
# Prediction of review # 10 =	 [0.7760413] 	 True values =  1
# Prediction of review # 11 =	 [0.00120138] 	 True values =  0
# Prediction of review # 12 =	 [0.04433475] 	 True values =  0
# Prediction of review # 13 =	 [0.00642033] 	 True values =  0
# Prediction of review # 14 =	 [0.9996654] 	 True values =  1
# Prediction of review # 15 =	 [1.059922e-05] 	 True values =  0
# ...

# %%
np.argmax(predictions[0])
# Out:
# 0

# %% [markdown]
# * Predictions array consists of probabilities of being 0 or 1 for each reviews
# * test_labels have 0 or 1, the true values

# %% [markdown]
# ### Plot results

# %%
acc      = history.history['acc']
val_acc  = history.history['val_acc']
loss     = history.history['loss']
val_loss = history.history['val_loss']
epochs   = range(1, len(acc)+1)

loss_epochs = plt.figure(figsize=(10,10))
sns.set()
plt.scatter(epochs, loss, marker='s', label='Training loss')
plt.scatter(epochs, val_loss, marker='o',label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
loss_epochs.savefig("loss_epochs")

# %%
acc_epochs = plt.figure(figsize=(10,10))
plt.scatter(epochs, acc, marker='s', label='Training acc')
plt.scatter(epochs, val_acc, marker='o', label='Validation acc')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
acc_epochs.savefig("acc_epochs")

# %%
history.history["val_acc"].__class__
# Out:
# list

# %% [markdown]
# * Accuracy on validation data is worse than training data $\rightarrow$ __Overfitting__
#   * The model became too specified to the training data
